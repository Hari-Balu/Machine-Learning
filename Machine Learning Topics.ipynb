# %% [markdown]
# # TOPICS

# %% [markdown]
# ![image.png](attachment:46867106-264e-42bd-a2dc-6b108e201133.png)

# %% [markdown]
# ![image.png](attachment:5d0018d1-d314-4a58-a471-8dabe78d2067.png)

# %% [markdown]
# ![image.png](attachment:965ad97f-9edf-42a6-ad71-1107cdc007be.png)

# %% [markdown]
# ![image.png](attachment:420421ee-231c-4ee0-be9f-ea8d443a8339.png)

# %% [markdown]
# ![image.png](attachment:95dce340-385e-4c7f-9358-6c95ebf77756.png)

# %% [markdown]
# ![image.png](attachment:0b36b86a-36d1-4074-9c66-0add464f9e01.png)
